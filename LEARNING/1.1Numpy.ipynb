# %% [markdown]
# # NUMPY **LIBRARY**

# %%
import numpy as np #import the library
lst = [2,3,4,5]
arr = np.array(lst)

# %%
arr #return the array
# Out:
# array([2, 3, 4, 5])

# %%
type(arr)
# Out:
# numpy.ndarray

# %%
arr.shape #return no of nows and columns
# Out:
# (4,)

# %%
lst1 = [2,3,4,5,6]
lst2 = [6,7,7,8,9]
lst3 = [2,3,5,6,7]
arr1 = np.array([lst1 , lst2 , lst3])

# %%
arr1
# Out:
# array([[2, 3, 4, 5, 6],
#        [6, 7, 7, 8, 9],
#        [2, 3, 5, 6, 7]])

# %%
arr1.shape
# Out:
# (3, 5)

# %% [markdown]
# # INDEXING FOR 1D ARRAY

# %%
arr[::-1] # to reverse the array
# Out:
# array([5, 4, 3, 2])

# %%
arr[1:4] #for a particular range
# Out:
# array([3, 4, 5])

# %%
arr[:-1] #return all elements except the last one
# Out:
# array([2, 3, 4])

# %%
arr[::-2] # element from the last and gap = 2
# Out:
# array([5, 3])

# %% [markdown]
# # INDEXING FOR MULTI-D ARRAY

# %%
arr1[:,1] #1st row ke saare elements
# Out:
# array([3, 7, 3])

# %%
arr1[1:,1:3]
# Out:
# array([[7, 7],
#        [3, 5]])
